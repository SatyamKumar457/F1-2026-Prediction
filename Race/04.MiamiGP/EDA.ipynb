# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AUS = pd.read_csv('Data/AustraliaGP.csv')

# %%
AUS
# Out:
#    Driver  FP1_BestTime(s)  FP2_BestTime(s)  FP3_BestTime(s)  Sector1Time(s)  \
# 0     ALB           83.130           81.847           81.664       36.650031
# 1     ANT           81.376           79.943           80.324       36.042935
# 2     BEA           82.682           81.326           80.778       39.039839
# 3     BOR           81.696           81.668           80.459       39.209964
# 4     BOT           84.022           83.660           83.514       37.285821
# 5     COL           83.325           82.619           81.413       38.297846
# 6     GAS           84.035           82.167           81.071       37.261133
# 7     HAD           81.087           80.941           80.137       36.938357
# 8     HAM           80.736           80.050           79.669       36.481677
# 9     HUL           81.969           81.351           81.067       34.139485
# 10    LAW           82.613           81.358           80.890       35.426966
# 11    LEC           80.267           80.291           79.827       37.004633
# 12    LIN           81.313           80.922           80.838       39.199867
# 13    NOR           84.391           80.794           80.443       33.216286
# 14    OCO           82.161           81.179           80.983       39.771345
# 15    PER           84.620              NaN           84.397       40.033500
# 16    PIA           81.342           79.729           80.087       36.638115
# 17    RUS           81.371           80.049           79.053       38.616071
# 18    SAI           82.323           82.253              NaN       35.224000
# 19    VER           80.789           80.366           80.197       37.872231
#
#     Sector2Time(s)  Sector3Time(s)  Average_Laptime(s)  Longest_Stint  \
# 0        20.898312       42.942393          100.398929             11
# 1        19.788161       41.798556           95.665077             15
# 2        20.835774       41.873786          102.072750             15
# 3        20.777286       46.708920           99.549182              9
# 4        20.556821       43.604600          101.500360             15
# 5        22.258222       45.171583          101.418318             11
# 6        22.742125       41.458429           99.050308             11
# 7        23.917321       42.749958           99.028217             13
# 8        21.753969       43.648655           99.920000             13
# 9        20.528765       41.426839           93.962483             10
# 10       21.766172       41.597720           97.647800             14
# 11       20.809667       45.400444           99.486360             10
# 12       20.971933       43.092519          101.070296             15
# 13       20.360862       42.638692           92.236042             16
# 14       20.526621       45.612115          102.046375             10
# 15       21.311000       53.610000          118.806000              2
# 16       20.288808       43.384000           96.971182             10
# 17       20.045714       42.000042          101.140833             13
# 18       21.142100       44.954667          102.363111              7
# 19       19.745000       41.107000           93.862300              5
#
#    Tyre_Compound  Qualifying_Time(s)  Starting_Pos  Race_Result
# 0           HARD              80.941          15.0         12.0
# 1           HARD              78.811           2.0          2.0
# 2           HARD              80.311          12.0          7.0
# 3         MEDIUM              80.221          10.0          9.0
# 4         MEDIUM              83.244          19.0         19.0
# 5         MEDIUM              81.270          16.0         14.0
# 6         MEDIUM              80.501          14.0         10.0
# 7         MEDIUM              79.303           3.0         20.0
# 8           HARD              79.478           7.0          4.0
# 9         MEDIUM              80.303          11.0         22.0
# 10        MEDIUM              79.994           8.0         13.0
# 11          HARD              79.327           4.0          3.0
# 12          SOFT              81.247           9.0          8.0
# 13          SOFT              79.475           6.0          5.0
# 14          HARD              80.491          13.0         11.0
# 15          SOFT              82.605          18.0         16.0
# 16          HARD              79.380           5.0         21.0
# 17          HARD              78.518           1.0          1.0
# 18        MEDIUM                 NaN           NaN         15.0
# 19        MEDIUM                 NaN           NaN          6.0

# %%
CHI = pd.read_csv('Data/ChinaGP.csv')

# %%
CHI
# Out:
#    Driver  FP1_BestTime(s)  FP2_BestTime(s)  FP3_BestTime(s)  Sector1Time(s)  \
# 0     ALB           95.480           95.305           98.158       27.300600
# 1     ALO           95.856           95.581           98.487       28.490000
# 2     ANT           92.861           91.809           94.760       28.116400
# 3     BEA           94.426           93.409           97.374       29.538154
# 4     BOR           94.828           93.774           97.800       28.943000
# 5     BOT           96.057           97.378           99.262       28.484571
# 6     COL           94.947           94.327           97.278       30.291600
# 7     GAS           94.676           92.888           98.349       29.145417
# 8     HAD           94.856           93.620           96.912       30.018583
# 9     HAM           94.129           92.161           94.926       28.891417
# 10    HUL           94.639           93.635           98.027       28.202083
# 11    LAW           94.773           93.714           97.882       27.259545
# 12    LEC           93.599           92.528           94.753       28.035833
# 13    LIN           97.896           94.048           98.475       27.856364
# 14    NOR           93.296           92.141           95.708       27.693500
# 15    OCO           94.877           93.639           97.363       27.888000
# 16    PER           99.200              NaN           98.862             NaN
# 17    PIA           93.472           92.224           95.635       28.373100
# 18    RUS           92.741           91.520           95.101       27.978700
# 19    SAI           95.679           94.761           97.913       29.112000
# 20    STR           97.224           96.151           98.532       29.756167
# 21    VER           94.541           93.254           95.774       29.153714
#
#     Sector2Time(s)  Sector3Time(s)  Average_Laptime(s)  Longest_Stint  \
# 0        31.527667       49.645000          108.962200            6.0
# 1        31.746600       48.075000          107.564250            5.0
# 2        32.863769       47.599231          107.658700            5.0
# 3        31.894063       48.543625          110.244462            7.0
# 4        32.736714       48.478214          110.359250            8.0
# 5        33.107250       48.428500          109.943714            8.0
# 6        33.194917       47.793000          111.528000            6.0
# 7        32.768933       49.672133          112.275500            6.0
# 8        31.808333       47.518714          107.512636            7.0
# 9        33.737000       49.144600          111.767250            5.0
# 10       33.229071       46.597000          107.721083            8.0
# 11       32.162615       48.857077          108.130000            7.0
# 12       31.963625       49.602250          108.046917            7.0
# 13       31.910154       48.277077          108.096091            7.0
# 14       31.314462       49.217769          108.887100            6.0
# 15       32.825308       49.634769          110.530091            7.0
# 16             NaN             NaN                 NaN            NaN
# 17       32.226769       48.985538          110.358700            6.0
# 18       32.987769       49.256538          109.650000            5.0
# 19       32.322000       48.965000          110.994200            6.0
# 20       33.753429       49.822143          113.359500            7.0
# 21       32.952235       47.594059          109.184500            7.0
#
#    Tyre_Compound  Qualifying_Time(s)  Starting_Pos  Race_Result
# 0         MEDIUM              94.772          18.0         22.0
# 1         MEDIUM              95.203          19.0         17.0
# 2         MEDIUM              92.064           1.0          1.0
# 3         MEDIUM              93.292          10.0          5.0
# 4         MEDIUM              93.965          16.0         21.0
# 5         MEDIUM              95.436          20.0         13.0
# 6         MEDIUM              93.357          12.0         10.0
# 7         MEDIUM              92.873           7.0          6.0
# 8         MEDIUM              93.121           9.0          8.0
# 9         MEDIUM              92.415           3.0          3.0
# 10        MEDIUM              93.354          11.0         11.0
# 11        MEDIUM              93.765          14.0          7.0
# 12        MEDIUM              92.428           4.0          4.0
# 13        MEDIUM              93.784          15.0         12.0
# 14        MEDIUM              92.608           6.0         20.0
# 15        MEDIUM              93.538          13.0         14.0
# 16           NaN              96.906          22.0         15.0
# 17        MEDIUM              92.550           5.0         19.0
# 18        MEDIUM              92.286           2.0          2.0
# 19        MEDIUM              94.317          17.0          9.0
# 20        MEDIUM              95.995          21.0         18.0
# 21        MEDIUM              93.002           8.0         16.0

# %%
JAP = pd.read_csv('Data/JapanGP.csv')

# %%
JAP
# Out:
#    Driver  FP1_BestTime(s)  FP2_BestTime(s)  FP3_BestTime(s)  Sector1Time(s)  \
# 0     ALB           93.697           91.496           91.733       42.531231
# 1     ANT           91.692           90.225           89.362       47.109174
# 2     BEA           92.900           91.498           91.558       43.953800
# 3     BOR           92.759           91.933           91.000       53.260667
# 4     BOT           94.490           92.615           92.503       43.989200
# 5     COL           93.361           92.438           91.759       43.006280
# 6     CRA           96.362              NaN              NaN             NaN
# 7     GAS           92.978           91.734           91.082       41.008560
# 8     HAD           92.803           91.759           91.094       45.154038
# 9     HAM           92.040           90.980           90.383       46.753333
# 10    HUL           92.798           91.441           90.658       42.662375
# 11    LAW           92.529           91.590           91.097       42.420000
# 12    LEC           91.955           90.846           90.229       43.150960
# 13    LIN           92.665              NaN           91.288             NaN
# 14    NOR           91.798           90.649           90.600       45.334286
# 15    OCO           92.601           91.532           91.326       43.407370
# 16    PER           94.221           93.689           92.540       47.314417
# 17    PIA           91.865           90.133           90.364       42.560769
# 18    RUS           91.666           90.338           89.616       47.393800
# 19    SAI           93.383           91.608           91.829       42.486538
# 20    STR           95.294           93.951           93.485       44.378000
# 21    VER           92.457           91.509           90.910       43.427846
#
#     Sector2Time(s)  Sector3Time(s)  Average_Laptime(s)  Longest_Stint  \
# 0        48.057667       21.567000          106.666583           11.0
# 1        45.386107       21.655821          103.388474           10.0
# 2        45.669714       22.014214          102.402952           15.0
# 3        48.081545       24.916545          119.585250            7.0
# 4        47.002679       21.424036          109.386375           15.0
# 5        47.661536       21.347107          104.757091           14.0
# 6              NaN             NaN                 NaN            NaN
# 7        46.617310       21.627517          106.528667           13.0
# 8        46.109931       21.571241          106.243957           14.0
# 9        49.164185       22.050000          104.465000            9.0
# 10       45.554074       22.005074          104.905045            8.0
# 11       47.320533       21.645833          107.318542           14.0
# 12       46.994536       22.093107          107.622043           12.0
# 13       69.262000       38.967000                 NaN            1.0
# 14       46.782176       24.024941          108.705583            9.0
# 15       46.763433       21.440467          104.676208           15.0
# 16       45.573786       22.538429          106.543600            9.0
# 17       45.652448       21.447586          105.411958           10.0
# 18       45.788276       22.059000          107.931045            9.0
# 19       46.049067       20.790467          105.217167           12.0
# 20       47.618476       21.998000          114.290000            7.0
# 21       44.212276       21.476103          103.802417           18.0
#
#    Tyre_Compound  Qualifying_Time(s)  Starting_Pos  Race_Result
# 0         MEDIUM              91.088          17.0         20.0
# 1         MEDIUM              88.778           1.0          1.0
# 2         MEDIUM              91.090          18.0         22.0
# 3           SOFT              90.274           9.0         13.0
# 4         MEDIUM              92.330          20.0         19.0
# 5         MEDIUM              90.627          15.0         16.0
# 6            NaN                 NaN           NaN          NaN
# 7           HARD              89.691           7.0          7.0
# 8           HARD              89.978           8.0         12.0
# 9         MEDIUM              89.567           6.0          6.0
# 10          HARD              90.387          13.0         11.0
# 11        MEDIUM              90.495          14.0          9.0
# 12        MEDIUM              89.405           4.0          3.0
# 13        MEDIUM              90.319          10.0         14.0
# 14          SOFT              89.409           5.0          5.0
# 15        MEDIUM              90.309          12.0         10.0
# 16          HARD              92.206          19.0         17.0
# 17        MEDIUM              89.132           3.0          2.0
# 18        MEDIUM              89.076           2.0          4.0
# 19          HARD              91.033          16.0         15.0
# 20          SOFT              92.920          22.0         21.0
# 21          HARD              90.262          11.0          8.0

# %%
MIA  = pd.read_csv('Data/MiamiGP.csv')

# %%
MIA
# Out:
#    Driver  FP1_BestTime(s)  FP2_BestTime(s)  FP3_BestTime(s)  Sector1Time(s)  \
# 0     ALB           91.024           90.216           93.473       40.930200
# 1     ALO           92.593           92.490           94.720       37.105200
# 2     ANT           90.079           88.091           91.932       39.886700
# 3     BEA           91.091           90.116           94.524       40.357000
# 4     BOR           91.111           89.994           94.174       37.460000
# 5     BOT           92.762           91.826           95.856       36.451500
# 6     COL           91.015           89.320           93.139       39.173833
# 7     GAS           90.587           89.474           93.072       39.254417
# 8     HAD           90.873           89.422           93.119       36.692083
# 9     HAM           89.777           88.618           92.448       38.031750
# 10    HUL           91.595           90.019              NaN       36.696111
# 11    LAW           91.648           91.043           94.204       35.239000
# 12    LEC           89.310           88.239           91.964       37.248333
# 13    LIN           92.862           90.573              NaN       35.695833
# 14    NOR           90.208           87.869           91.885       36.548167
# 15    OCO           91.635           91.245           94.409       37.663500
# 16    PER           92.047           91.255           95.015       36.188500
# 17    PIA           89.758           88.108           92.079       39.577889
# 18    RUS           90.100           88.493           92.387       39.324091
# 19    SAI           90.930           90.224           94.008       39.058700
# 20    STR           92.959              NaN           95.009       37.744000
# 21    VER           89.607           88.461           92.201       37.386556
#
#     Sector2Time(s)  Sector3Time(s)  Average_Laptime(s)  Longest_Stint  \
# 0        40.687333       31.818667          112.258500              6
# 1        39.793167       34.718667          111.428600              6
# 2        40.724857       33.187923          106.295500              3
# 3        39.887444       31.671333          110.144833              3
# 4        41.726500       33.908167          111.922889              6
# 5        40.314667       36.732800           92.071500              3
# 6        39.762400       31.374500          109.832000              6
# 7        40.081667       30.743786          109.097636              6
# 8        40.412400       31.293143          106.426636              6
# 9        39.298200       30.978429          107.213273              6
# 10       39.646000       35.762417          111.277667              6
# 11       41.875400       33.851400          108.776667              3
# 12       40.522133       30.256286          107.127000              6
# 13       39.129333       37.534111          112.617000              3
# 14       40.037467       32.785571          108.265727              7
# 15       40.661667       31.575000          108.342250              3
# 16       40.089333       42.648333          122.447500              3
# 17       40.305273       33.269778          111.682429              5
# 18       40.503000       34.202357          106.589556              3
# 19       41.538333       31.354167          111.177600              6
# 20       39.904000       43.944667          125.395000              3
# 21       39.817500       30.584364          105.282000              6
#
#    Tyre_Compound  Qualifying_Time(s)  Starting_Pos
# 0         MEDIUM              89.946          16.0
# 1         MEDIUM              91.098          18.0
# 2         MEDIUM              87.798           1.0
# 3         MEDIUM              89.567          13.0
# 4         MEDIUM              93.737          22.0
# 5         MEDIUM              91.629          20.0
# 6         MEDIUM              88.762           8.0
# 7         MEDIUM              88.810          10.0
# 8         MEDIUM              88.789           9.0
# 9         MEDIUM              88.319           6.0
# 10        MEDIUM              89.439          11.0
# 11        MEDIUM              89.499          12.0
# 12        MEDIUM              88.143           3.0
# 13        MEDIUM              90.133          17.0
# 14        MEDIUM              88.183           4.0
# 15        MEDIUM              89.772          15.0
# 16        MEDIUM              91.967          21.0
# 17        MEDIUM              88.500           7.0
# 18        MEDIUM              88.197           5.0
# 19        MEDIUM              89.568          14.0
# 20        MEDIUM              91.164          19.0
# 21        MEDIUM              87.964           2.0

# %%
TRA = pd.concat([AUS,CHI,JAP],axis=0)

# %%
TRA
# Out:
#    Driver  FP1_BestTime(s)  FP2_BestTime(s)  FP3_BestTime(s)  Sector1Time(s)  \
# 0     ALB           83.130           81.847           81.664       36.650031
# 1     ANT           81.376           79.943           80.324       36.042935
# 2     BEA           82.682           81.326           80.778       39.039839
# 3     BOR           81.696           81.668           80.459       39.209964
# 4     BOT           84.022           83.660           83.514       37.285821
# ..    ...              ...              ...              ...             ...
# 17    PIA           91.865           90.133           90.364       42.560769
# 18    RUS           91.666           90.338           89.616       47.393800
# 19    SAI           93.383           91.608           91.829       42.486538
# 20    STR           95.294           93.951           93.485       44.378000
# 21    VER           92.457           91.509           90.910       43.427846
#
#     Sector2Time(s)  Sector3Time(s)  Average_Laptime(s)  Longest_Stint  \
# 0        20.898312       42.942393          100.398929           11.0
# 1        19.788161       41.798556           95.665077           15.0
# 2        20.835774       41.873786          102.072750           15.0
# 3        20.777286       46.708920           99.549182            9.0
# 4        20.556821       43.604600          101.500360           15.0
# ..             ...             ...                 ...            ...
# 17       45.652448       21.447586          105.411958           10.0
# 18       45.788276       22.059000          107.931045            9.0
# 19       46.049067       20.790467          105.217167           12.0
# 20       47.618476       21.998000          114.290000            7.0
# 21       44.212276       21.476103          103.802417           18.0
#
#    Tyre_Compound  Qualifying_Time(s)  Starting_Pos  Race_Result
# 0           HARD              80.941          15.0         12.0
# 1           HARD              78.811           2.0          2.0
# 2           HARD              80.311          12.0          7.0
# 3         MEDIUM              80.221          10.0          9.0
# 4         MEDIUM              83.244          19.0         19.0
# ..           ...                 ...           ...          ...
# 17        MEDIUM              89.132           3.0          2.0
# 18        MEDIUM              89.076           2.0          4.0
# 19          HARD              91.033          16.0         15.0
# 20          SOFT              92.920          22.0         21.0
# 21          HARD              90.262          11.0          8.0
#
# [64 rows x 13 columns]

# %%
TRA.isnull().sum()
# Out:
# Driver                0
# FP1_BestTime(s)       0
# FP2_BestTime(s)       4
# FP3_BestTime(s)       2
# Sector1Time(s)        3
# Sector2Time(s)        2
# Sector3Time(s)        2
# Average_Laptime(s)    3
# Longest_Stint         2
# Tyre_Compound         2
# Qualifying_Time(s)    3
# Starting_Pos          3
# Race_Result           1
# dtype: int64

# %%
TRA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64 entries, 0 to 21
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Driver              64 non-null     object
#  1   FP1_BestTime(s)     64 non-null     float64
#  2   FP2_BestTime(s)     60 non-null     float64
#  3   FP3_BestTime(s)     62 non-null     float64
#  4   Sector1Time(s)      61 non-null     float64
#  5   Sector2Time(s)      62 non-null     float64
#  6   Sector3Time(s)      62 non-null     float64
#  7   Average_Laptime(s)  61 non-null     float64
#  8   Longest_Stint       62 non-null     float64
#  9   Tyre_Compound       62 non-null     object
#  10  Qualifying_Time(s)  61 non-null     float64
#  11  Starting_Pos        61 non-null     float64
#  12  Race_Result         63 non-null     float64
# dtypes: float64(11), object(2)
# memory usage: 7.0+ KB

# %%
TRA.dropna(subset=['Qualifying_Time(s)','Race_Result'],inplace=True)

# %%
TRA.isnull().sum()
# Out:
# Driver                0
# FP1_BestTime(s)       0
# FP2_BestTime(s)       3
# FP3_BestTime(s)       0
# Sector1Time(s)        2
# Sector2Time(s)        1
# Sector3Time(s)        1
# Average_Laptime(s)    2
# Longest_Stint         1
# Tyre_Compound         1
# Qualifying_Time(s)    0
# Starting_Pos          0
# Race_Result           0
# dtype: int64

# %%
TRA['FP2_BestTime(s)'].fillna(TRA['FP2_BestTime(s)'].median(),inplace=True)
TRA['Sector1Time(s)'].fillna(TRA['Sector1Time(s)'].median(),inplace=True)
TRA['Sector2Time(s)'].fillna(TRA['Sector2Time(s)'].median(),inplace=True)
TRA['Sector3Time(s)'].fillna(TRA['Sector3Time(s)'].median(),inplace=True)
TRA['Average_Laptime(s)'].fillna(TRA['Average_Laptime(s)'].mean(),inplace=True)
TRA['Longest_Stint'].fillna(TRA['Longest_Stint'].median(),inplace=True)
TRA['Tyre_Compound'].fillna(TRA['Tyre_Compound'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_14632/4004369100.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['FP2_BestTime(s)'].fillna(TRA['FP2_BestTime(s)'].median(),inplace=True)
# /tmp/ipykernel_14632/4004369100.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Sector1Time(s)'].fillna(TRA['Sector1Time(s)'].median(),inplace=True)
# /tmp/ipykernel_14632/4004369100.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Sector2Time(s)'].fillna(TRA['Sector2Time(s)'].median(),inplace=True)
# /tmp/ipykernel_14632/4004369100.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Sector3Time(s)'].fillna(TRA['Sector3Time(s)'].median(),inplace=True)
# /tmp/ipykernel_14632/4004369100.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Average_Laptime(s)'].fillna(TRA['Average_Laptime(s)'].mean(),inplace=True)
# /tmp/ipykernel_14632/4004369100.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Longest_Stint'].fillna(TRA['Longest_Stint'].median(),inplace=True)

# %%
TRA.isnull().sum()
# Out:
# Driver                0
# FP1_BestTime(s)       0
# FP2_BestTime(s)       0
# FP3_BestTime(s)       0
# Sector1Time(s)        0
# Sector2Time(s)        0
# Sector3Time(s)        0
# Average_Laptime(s)    0
# Longest_Stint         0
# Tyre_Compound         0
# Qualifying_Time(s)    0
# Starting_Pos          0
# Race_Result           0
# dtype: int64

# %%
TRA.to_csv('TrainingData.csv',index=False)

# %%
PRE = MIA.copy()

# %%
PRE.isnull().sum()
# Out:
# Driver                0
# FP1_BestTime(s)       0
# FP2_BestTime(s)       1
# FP3_BestTime(s)       2
# Sector1Time(s)        0
# Sector2Time(s)        0
# Sector3Time(s)        0
# Average_Laptime(s)    0
# Longest_Stint         0
# Tyre_Compound         0
# Qualifying_Time(s)    0
# Starting_Pos          0
# dtype: int64

# %%
PRE['FP2_BestTime(s)'].fillna(PRE['FP2_BestTime(s)'].median(),inplace=True)
PRE['FP3_BestTime(s)'].fillna(PRE['FP3_BestTime(s)'].median(),inplace=True)
# Out:
# /tmp/ipykernel_14632/4120230503.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   PRE['FP2_BestTime(s)'].fillna(PRE['FP2_BestTime(s)'].median(),inplace=True)
# /tmp/ipykernel_14632/4120230503.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   PRE['FP3_BestTime(s)'].fillna(PRE['FP3_BestTime(s)'].median(),inplace=True)

# %%
PRE.isnull().sum()
# Out:
# Driver                0
# FP1_BestTime(s)       0
# FP2_BestTime(s)       0
# FP3_BestTime(s)       0
# Sector1Time(s)        0
# Sector2Time(s)        0
# Sector3Time(s)        0
# Average_Laptime(s)    0
# Longest_Stint         0
# Tyre_Compound         0
# Qualifying_Time(s)    0
# Starting_Pos          0
# dtype: int64

# %%
PRE.to_csv('PredictionData.csv',index=False)
