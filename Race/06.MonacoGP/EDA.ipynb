# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AUS = pd.read_csv('Data/AustraliaGP.csv')
CHI = pd.read_csv('Data/ChinaGP.csv')
JAP = pd.read_csv('Data/JapanGP.csv')
MIA  = pd.read_csv('Data/MiamiGP.csv')
CAN = pd.read_csv('Data/CanadaGP.csv')

# %%
TRA = pd.concat([AUS,CHI,JAP,MIA,CAN],axis=0)

# %%
TRA
# Out:
#    Driver      Constructor  AveragePositionFromLast3Races  \
# 0     ALB         Williams                       6.000000
# 1     ALO     Aston Martin                       9.000000
# 2     ANT         Mercedes                      10.000000
# 3     BEA     Haas F1 Team                       6.500000
# 4     BOR             Audi                       5.500000
# ..    ...              ...                            ...
# 17    PIA          McLaren                       5.333333
# 18    RUS         Mercedes                       9.000000
# 19    SAI         Williams                      11.000000
# 20    STR     Aston Martin                      17.666667
# 21    VER  Red Bull Racing                       5.333333
#
#     AveragePointsFromLast3Races  ConstructorAveragePointFromLast3Races  \
# 0                           NaN                               0.000000
# 1                           NaN                               0.000000
# 2                           NaN                              43.000000
# 3                           NaN                               6.000000
# 4                           NaN                               2.000000
# ..                          ...                                    ...
# 17                    11.000000                              20.333333
# 18                     8.000000                              33.000000
# 19                     1.333333                               1.666667
# 20                     0.000000                               0.000000
# 21                     9.666667                              13.000000
#
#     FP1_BestTime(s)  FP2_BestTime(s)  FP3_BestTime(s)  Sector1Time(s)  \
# 0            83.130           81.847           81.664       36.650031
# 1               NaN           84.662           82.720       35.042333
# 2            81.376           79.943           80.324       36.042935
# 3            82.682           81.326           80.778       39.039839
# 4            81.696           81.668           80.459       39.209964
# ..              ...              ...              ...             ...
# 17           74.963           73.299           74.793       27.788600
# 18           73.544           72.965           74.702       24.087889
# 19           76.660           74.536           75.943       26.809000
# 20           76.978           76.354           77.120       26.713857
# 21           74.366           73.504           74.974       25.239286
#
#     Sector2Time(s)  Sector3Time(s)  Average_Laptime(s)  Qualifying_Time(s)  \
# 0        20.898312       42.942393          100.398929              80.941
# 1        23.232611       50.321933          105.833357              81.969
# 2        19.788161       41.798556           95.665077              78.811
# 3        20.835774       41.873786          102.072750              80.311
# 4        20.777286       46.708920           99.549182              80.221
# ..             ...             ...                 ...                 ...
# 17       27.393933       37.005167           91.068583              72.781
# 18       26.450421       36.526353           87.752375              72.578
# 19       27.738625       34.576850           87.875158              74.273
# 20       27.152500       36.901429           91.682000              76.195
# 21       26.922500       34.624667           85.870167              72.907
#
#     Starting_Pos  Race_Result  DriverPoints  ConstructorPoints
# 0           15.0         12.0           0.0                0.0
# 1           17.0         18.0           0.0                0.0
# 2            2.0          2.0          18.0               43.0
# 3           12.0          7.0           6.0                6.0
# 4           10.0          9.0           2.0                2.0
# ..           ...          ...           ...                ...
# 17           4.0         11.0           0.0                0.0
# 18           1.0         19.0           0.0               25.0
# 19          15.0          9.0           2.0                2.0
# 20          21.0         15.0           0.0                0.0
# 21           6.0          3.0          15.0               25.0
#
# [110 rows x 17 columns]

# %%
TRA.isnull().sum()
# Out:
# Driver                                    0
# Constructor                               0
# AveragePositionFromLast3Races             0
# AveragePointsFromLast3Races              22
# ConstructorAveragePointFromLast3Races     0
# FP1_BestTime(s)                           4
# FP2_BestTime(s)                           7
# FP3_BestTime(s)                           4
# Sector1Time(s)                            4
# Sector2Time(s)                            3
# Sector3Time(s)                            3
# Average_Laptime(s)                        4
# Qualifying_Time(s)                        3
# Starting_Pos                              3
# Race_Result                               0
# DriverPoints                              0
# ConstructorPoints                         0
# dtype: int64

# %%
TRA.dropna(subset=['Qualifying_Time(s)','Race_Result'],inplace=True)

# %%
TRA.isnull().sum()
# Out:
# Driver                                    0
# Constructor                               0
# AveragePositionFromLast3Races             0
# AveragePointsFromLast3Races              19
# ConstructorAveragePointFromLast3Races     0
# FP1_BestTime(s)                           3
# FP2_BestTime(s)                           6
# FP3_BestTime(s)                           2
# Sector1Time(s)                            4
# Sector2Time(s)                            3
# Sector3Time(s)                            3
# Average_Laptime(s)                        4
# Qualifying_Time(s)                        0
# Starting_Pos                              0
# Race_Result                               0
# DriverPoints                              0
# ConstructorPoints                         0
# dtype: int64

# %%
TRA['FP1_BestTime(s)'].fillna(TRA['FP1_BestTime(s)'].median(),inplace=True)
TRA['FP2_BestTime(s)'].fillna(TRA['FP2_BestTime(s)'].median(),inplace=True)
TRA['FP3_BestTime(s)'].fillna(TRA['FP3_BestTime(s)'].median(),inplace=True)
TRA['Sector1Time(s)'].fillna(TRA['Sector1Time(s)'].median(),inplace=True)
TRA['Sector2Time(s)'].fillna(TRA['Sector2Time(s)'].median(),inplace=True)
TRA['Sector3Time(s)'].fillna(TRA['Sector3Time(s)'].median(),inplace=True)
TRA['Average_Laptime(s)'].fillna(TRA['Average_Laptime(s)'].mean(),inplace=True)
# Out:
# /tmp/ipykernel_52109/1266289316.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['FP1_BestTime(s)'].fillna(TRA['FP1_BestTime(s)'].median(),inplace=True)
# /tmp/ipykernel_52109/1266289316.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['FP2_BestTime(s)'].fillna(TRA['FP2_BestTime(s)'].median(),inplace=True)
# /tmp/ipykernel_52109/1266289316.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['FP3_BestTime(s)'].fillna(TRA['FP3_BestTime(s)'].median(),inplace=True)
# /tmp/ipykernel_52109/1266289316.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Sector1Time(s)'].fillna(TRA['Sector1Time(s)'].median(),inplace=True)
# /tmp/ipykernel_52109/1266289316.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Sector2Time(s)'].fillna(TRA['Sector2Time(s)'].median(),inplace=True)
# /tmp/ipykernel_52109/1266289316.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Sector3Time(s)'].fillna(TRA['Sector3Time(s)'].median(),inplace=True)
# /tmp/ipykernel_52109/1266289316.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['Average_Laptime(s)'].fillna(TRA['Average_Laptime(s)'].mean(),inplace=True)

# %%
TRA.isnull().sum()
# Out:
# Driver                                    0
# Constructor                               0
# AveragePositionFromLast3Races             0
# AveragePointsFromLast3Races              19
# ConstructorAveragePointFromLast3Races     0
# FP1_BestTime(s)                           0
# FP2_BestTime(s)                           0
# FP3_BestTime(s)                           0
# Sector1Time(s)                            0
# Sector2Time(s)                            0
# Sector3Time(s)                            0
# Average_Laptime(s)                        0
# Qualifying_Time(s)                        0
# Starting_Pos                              0
# Race_Result                               0
# DriverPoints                              0
# ConstructorPoints                         0
# dtype: int64

# %%
TRA['AveragePointsFromLast3Races'].fillna(0,inplace=True)
# Out:
# /tmp/ipykernel_52109/3824625917.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TRA['AveragePointsFromLast3Races'].fillna(0,inplace=True)

# %%
TRA.isnull().sum()
# Out:
# Driver                                   0
# Constructor                              0
# AveragePositionFromLast3Races            0
# AveragePointsFromLast3Races              0
# ConstructorAveragePointFromLast3Races    0
# FP1_BestTime(s)                          0
# FP2_BestTime(s)                          0
# FP3_BestTime(s)                          0
# Sector1Time(s)                           0
# Sector2Time(s)                           0
# Sector3Time(s)                           0
# Average_Laptime(s)                       0
# Qualifying_Time(s)                       0
# Starting_Pos                             0
# Race_Result                              0
# DriverPoints                             0
# ConstructorPoints                        0
# dtype: int64
